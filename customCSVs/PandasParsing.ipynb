# %%
import pandas as pd
import csv

# %%
df = pd.read_csv('../WikiArtClean.csv')
df = df.drop(columns=['Image URL', 'Painting Info URL', 'Artist Info URL'])
df.head()
# Out:
#              Style              Category         Artist  \
# 0  Renaissance Art  Northern Renaissance  Robert Campin
# 1  Renaissance Art     Early Renaissance       Masaccio
# 2  Renaissance Art  Northern Renaissance  Robert Campin
# 3  Renaissance Art     Early Renaissance       Masaccio
# 4  Renaissance Art     Early Renaissance       Masaccio
#
#                                                Title  Year Is painting  \
# 0  Triptych: The Two Thieves with the Empty Cross...  1415         yes
# 1                               St. Juvenal Triptych  1422         yes
# 2                 Blessing Christ and Praying Virgin  1424         yes
# 3                                  The Tribute Money  1425         yes
# 4                                           St. Paul  1426         yes
#
#   Face or body  Mean rating  Agreeableness  Anger  ...   Love  Optimism  \
# 0         face         1.20            0.0  0.100  ...  0.000     0.000
# 1         face         1.06            0.0  0.000  ...  0.313     0.188
# 2         face         1.60            0.1  0.000  ...  0.300     0.200
# 3         face         1.08            0.0  0.083  ...  0.000     0.083
# 4         face         1.45            0.0  0.000  ...  0.091     0.273
#
#    Pessimism  Regret  Sadness  Shame  Shyness  Surprise  Trust  Neutral
# 0      0.000     0.1    0.400  0.000      0.0     0.100  0.500      0.0
# 1      0.000     0.0    0.063  0.000      0.0     0.000  0.688      0.0
# 2      0.000     0.1    0.000  0.000      0.0     0.000  0.600      0.0
# 3      0.083     0.0    0.000  0.083      0.0     0.167  0.500      0.0
# 4      0.000     0.0    0.364  0.000      0.0     0.091  0.364      0.0
#
# [5 rows x 28 columns]

# %%
# Getting all different styles
styles = []

for index, row in df.iterrows():
    if row[0] not in styles:
        styles.append(row[0])
        
styles
# Out:
# ['Renaissance Art',
#  'Post Renaissance Art',
#  'Modern Art',
#  'Modern Art,Post Renaissance Art',
#  'Contemporary Art,Modern Art',
#  'Contemporary Art']

# %%
# Creating dataframes f
styleFrames = [];

for style in styles:
    newDf = df.loc[df['Style'] == style]
    styleFrames.append(newDf)
# Out:
#                Style              Category           Artist  \
# 0    Renaissance Art  Northern Renaissance    Robert Campin
# 1    Renaissance Art     Early Renaissance         Masaccio
# 2    Renaissance Art  Northern Renaissance    Robert Campin
# 3    Renaissance Art     Early Renaissance         Masaccio
# 4    Renaissance Art     Early Renaissance         Masaccio
# ..               ...                   ...              ...
# 304  Renaissance Art  Northern Renaissance  Joachim Wtewael
# 312  Renaissance Art  Northern Renaissance  Joachim Wtewael
# 315  Renaissance Art  Northern Renaissance     Jan Provoost
# 322  Renaissance Art  Northern Renaissance  Joachim Wtewael
# 355  Renaissance Art  Northern Renaissance  Joachim Wtewael
#
#                                                  Title  Year Is painting  \
# 0    Triptych: The Two Thieves with the Empty Cross...  1415         yes
# 1                                 St. Juvenal Triptych  1422         yes
# 2                   Blessing Christ and Praying Virgin  1424         yes
# 3                                    The Tribute Money  1425         yes
# 4                                             St. Paul  1426         yes
# ..                                                 ...   ...         ...
# 304                         Martyrdom of St. Sebastian  1600         yes
# 312                                      Kitchen Scene  1605         yes
# 315                     The Martyrdom of St. Catherine  1607         yes
# 322                         Perseus Rescuing Andromeda  1611         yes
# 355                         Adoration by the Shepherds  1625         yes
#
#     Face or body  Mean rating  Agreeableness  Anger  ...   Love  Optimism  \
# 0           face         1.20          0.000  0.100  ...  0.000     0.000
# 1           face         1.06          0.000  0.000  ...  0.313     0.188
# 2           face         1.60          0.100  0.000  ...  0.300     0.200
# 3           face         1.08          0.000  0.083  ...  0.000     0.083
# 4           face         1.45          0.000  0.000  ...  0.091     0.273
# ..           ...          ...            ...    ...  ...    ...       ...
# 304         face         1.70          0.100  0.100  ...  0.300     0.200
# 312         face         0.80          0.111  0.000  ...  0.111     0.222
# 315         face         1.60          0.100  0.100  ...  0.100     0.000
# 322         face         1.83          0.000  0.167  ...  0.417     0.333
# 355         face         1.60          0.000  0.000  ...  0.500     0.200
#
#      Pessimism  Regret  Sadness  Shame  Shyness  Surprise  Trust  Neutral
# 0        0.000     0.1    0.400  0.000      0.0     0.100  0.500      0.0
# 1        0.000     0.0    0.063  0.000      0.0     0.000  0.688      0.0
# 2        0.000     0.1    0.000  0.000      0.0     0.000  0.600      0.0
# 3        0.083     0.0    0.000  0.083      0.0     0.167  0.500      0.0
# 4        0.000     0.0    0.364  0.000      0.0     0.091  0.364      0.0
# ..         ...     ...      ...    ...      ...       ...    ...      ...
# 304      0.100     0.0    0.400  0.100      0.0     0.100  0.300      0.0
# 312      0.000     0.0    0.000  0.000      0.0     0.000  0.000      0.0
# 315      0.200     0.1    0.600  0.500      0.0     0.000  0.300      0.0
# 322      0.000     0.0    0.000  0.000      0.0     0.167  0.667      0.0
# 355      0.000     0.0    0.000  0.000      0.0     0.100  0.600      0.0
#
# [287 rows x 28 columns]

# %%
for i in range(len(styles)):
    finalCsv = pd.DataFrame(styleFrames[i])
    fileName = styles[i] + '.csv'
    finalCsv.to_csv(fileName)
